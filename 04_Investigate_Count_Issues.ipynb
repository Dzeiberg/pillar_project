# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
pillar_df = pd.read_csv("/data/dzeiberg/pillar_project/dataframe/pillar_data_clinvar38_annotated_final_v13_expanded_031425.csv")
# Out:
# /tmp/ipykernel_3151406/807609826.py:1: DtypeWarning: Columns (4,11,13,14,15,21,22,23,34,37,38,39,40,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   pillar_df = pd.read_csv("/data/dzeiberg/pillar_project/dataframe/pillar_data_clinvar38_annotated_final_v13_expanded_031425.csv")

# %%
pillar_df[(pillar_df.Dataset.str.startswith("CBS_Sun")) & \
          (pillar_df.clinvar_sig.isin({"Benign", "Benign/Likely_benign", "Likely_benign"}))]
# Out:
#                                    ID               Dataset Gene  HGNC_id  \
# 58545  CBS_Sun_2020_high_B6_var373612  CBS_Sun_2020_high_B6  CBS   1550.0
# 67116  CBS_Sun_2020_high_B6_var382183  CBS_Sun_2020_high_B6  CBS   1550.0
# 69433   CBS_Sun_2020_low_B6_var384500   CBS_Sun_2020_low_B6  CBS   1550.0
# 78522   CBS_Sun_2020_low_B6_var393589   CBS_Sun_2020_low_B6  CBS   1550.0
#
#       Chrom  STRAND  hg19_pos  hg38_start    hg38_end ref_allele alt_allele  \
# 58545    21    -1.0       NaN  43065417.0  43065417.0          G          A
# 67116    21    -1.0       NaN  43065240.0  43065240.0          G          A
# 69433    21    -1.0       NaN  43065417.0  43065417.0          G          A
# 78522    21    -1.0       NaN  43065240.0  43065240.0          G          A
#
#       auth_transcript_id transcript_pos transcript_ref transcript_alt aa_pos  \
# 58545                NaN            636            NaN            NaN  212.0
# 67116                NaN            699            NaN            NaN    233
# 69433                NaN            636            NaN            NaN    212
# 78522                NaN            699            NaN            NaN    233
#
#       aa_ref aa_alt    hgvs_c     hgvs_p         consequence  \
# 58545      N      =  c.636C>T  p.Asn212=  synonymous_variant
# 67116      Y      =  c.699C>T  p.Tyr233=  synonymous_variant
# 69433      N      =  c.636C>T  p.Asn212=  synonymous_variant
# 78522      Y      =  c.699C>T  p.Tyr233=  synonymous_variant
#
#       auth_reported_score auth_reported_rep_score auth_reported_func_class  \
# 58545             1.13464                     NaN                      NaN
# 67116             1.07011                     NaN                      NaN
# 69433            1.080691                     NaN                      NaN
# 78522            1.005049                     NaN                      NaN
#
#        auth_reported_normal_min  auth_reported_normal_max  \
# 58545                       NaN                       NaN
# 67116                       NaN                       NaN
# 69433                       NaN                       NaN
# 78522                       NaN                       NaN
#
#        auth_reported_abnormal_min  auth_reported_abnormal_max splice_measure  \
# 58545                         NaN                         NaN             No
# 67116                         NaN                         NaN             No
# 69433                         NaN                         NaN             No
# 78522                         NaN                         NaN             No
#
#        gnomad_MAF clinvar_sig  \
# 58545    0.001846      Benign
# 67116         NaN      Benign
# 69433    0.001846      Benign
# 78522         NaN      Benign
#
#                                             clinvar_star  \
# 58545  criteria provided, multiple submitters, no con...
# 67116  criteria provided, multiple submitters, no con...
# 69433  criteria provided, multiple submitters, no con...
# 78522  criteria provided, multiple submitters, no con...
#
#       clinvar_date_last_reviewed nucleotide_or_aa   MaveDB URN (score set)  \
# 58545               Jan 29, 2024               aa  urn:mavedb:00000005-a-6
# 67116               Feb 01, 2024               aa  urn:mavedb:00000005-a-6
# 69433               Jan 29, 2024               aa  urn:mavedb:00000005-a-5
# 78522               Feb 01, 2024               aa  urn:mavedb:00000005-a-5
#
#       Ensembl_transript_ID Ref_seq_transcript_ID Model_system      Assay_type  \
# 58545    ENST00000398165.8           NM_000071.3        yeast  Cell viability
# 67116    ENST00000398165.8           NM_000071.3        yeast  Cell viability
# 69433    ENST00000398165.8           NM_000071.3        yeast  Cell viability
# 78522    ENST00000398165.8           NM_000071.3        yeast  Cell viability
#
#       Phenotype_measured Phenotype_detail IGVF_produced  \
# 58545                NaN              NaN            No
# 67116                NaN              NaN            No
# 69433                NaN              NaN            No
# 78522                NaN              NaN            No
#
#       simplified_consequence Flag
# 58545             Synonymous  NaN
# 67116             Synonymous  NaN
# 69433             Synonymous  NaN
# 78522             Synonymous  NaN

# %%
|
