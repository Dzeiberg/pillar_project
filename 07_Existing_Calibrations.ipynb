# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
ls /data/dzeiberg/pillar_project/dataframe/
# Out:
# counts_final.csv
# Datasets_03262025.csv
# final_scoresets/
# old/
# pillar_data_clinvar38_annotated_final_v14_spliceai_032525.csv
# processed_scoresets/
# spliceai_merging/

# %%
dataframe = pd.read_csv("/data/dzeiberg/pillar_project/dataframe/pillar_data_clinvar38_annotated_final_v14_spliceai_032525.csv")
# Out:
# /tmp/ipykernel_3780504/84668670.py:1: DtypeWarning: Columns (4,11,13,14,15,21,22,23,34,37,38,39,40,43,44,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe = pd.read_csv("/data/dzeiberg/pillar_project/dataframe/pillar_data_clinvar38_annotated_final_v14_spliceai_032525.csv")

# %%
dataframe
# Out:
#                                                      ID  \
# 0        ASPA_Grønbæk-Thygesen_2024_abundance_var288098
# 1        ASPA_Grønbæk-Thygesen_2024_abundance_var288098
# 2        ASPA_Grønbæk-Thygesen_2024_abundance_var288098
# 3        ASPA_Grønbæk-Thygesen_2024_abundance_var288098
# 4        ASPA_Grønbæk-Thygesen_2024_abundance_var288099
# ...                                                 ...
# 1053709                      PTEN_Mighell_2018_var96397
# 1053710                      PTEN_Mighell_2018_var96399
# 1053711                      PTEN_Mighell_2018_var96402
# 1053712                      PTEN_Mighell_2018_var96408
# 1053713                      PTEN_Mighell_2018_var96414
#
#                                       Dataset  Gene  HGNC_id Chrom  STRAND  \
# 0        ASPA_Grønbæk-Thygesen_2024_abundance  ASPA    756.0    17     1.0
# 1        ASPA_Grønbæk-Thygesen_2024_abundance  ASPA    756.0    17     1.0
# 2        ASPA_Grønbæk-Thygesen_2024_abundance  ASPA    756.0    17     1.0
# 3        ASPA_Grønbæk-Thygesen_2024_abundance  ASPA    756.0    17     1.0
# 4        ASPA_Grønbæk-Thygesen_2024_abundance  ASPA    756.0    17     1.0
# ...                                       ...   ...      ...   ...     ...
# 1053709                     PTEN_Mighell_2018  PTEN   9588.0    10     1.0
# 1053710                     PTEN_Mighell_2018  PTEN   9588.0    10     1.0
# 1053711                     PTEN_Mighell_2018  PTEN   9588.0    10     1.0
# 1053712                     PTEN_Mighell_2018  PTEN   9588.0    10     1.0
# 1053713                     PTEN_Mighell_2018  PTEN   9588.0    10     1.0
#
#          hg19_pos  hg38_start    hg38_end ref_allele alt_allele  \
# 0             NaN   3476163.0   3476163.0          A          G
# 1             NaN   3476163.0   3476165.0        ACT        GCC
# 2             NaN   3476163.0   3476165.0        ACT        GCA
# 3             NaN   3476163.0   3476165.0        ACT        GCG
# 4             NaN   3476163.0   3476164.0         AC         TG
# ...           ...         ...         ...        ...        ...
# 1053709       NaN  87965467.0  87965469.0        GTC        ATT
# 1053710       NaN  87965467.0  87965469.0        GTC        ATG
# 1053711       NaN  87965467.0  87965469.0        GTC        TGG
# 1053712       NaN  87965468.0  87965469.0         TC         GT
# 1053713       NaN  87965468.0  87965469.0         TC         AA
#
#         auth_transcript_id transcript_pos transcript_ref transcript_alt  \
# 0                      NaN              4            NaN            NaN
# 1                      NaN            4-6            NaN            NaN
# 2                      NaN            4-6            NaN            NaN
# 3                      NaN            4-6            NaN            NaN
# 4                      NaN            4-5            NaN            NaN
# ...                    ...            ...            ...            ...
# 1053709        NM_000314.6      1207-1209            NaN            NaN
# 1053710        NM_000314.6      1207-1209            NaN            NaN
# 1053711        NM_000314.6      1207-1209            NaN            NaN
# 1053712        NM_000314.6      1208-1209            NaN            NaN
# 1053713        NM_000314.6      1208-1209            NaN            NaN
#
#         aa_pos aa_ref aa_alt                hgvs_c       hgvs_p  \
# 0            2      T      A                c.4A>G    p.Thr2Ala
# 1            2      T      A        c.4_6delinsGCC    p.Thr2Ala
# 2            2      T      A        c.4_6delinsGCA    p.Thr2Ala
# 3            2      T      A        c.4_6delinsGCG    p.Thr2Ala
# 4            2      T      C         c.4_5delinsTG    p.Thr2Cys
# ...        ...    ...    ...                   ...          ...
# 1053709  403.0      V      I  c.1207_1209delinsATT  p.Val403Ile
# 1053710  403.0      V      M  c.1207_1209delinsATG  p.Val403Met
# 1053711  403.0      V      W  c.1207_1209delinsTGG  p.Val403Trp
# 1053712  403.0      V      G   c.1208_1209delinsGT  p.Val403Gly
# 1053713  403.0      V      E   c.1208_1209delinsAA  p.Val403Glu
#
#               consequence auth_reported_score auth_reported_rep_score  \
# 0        missense_variant              0.9031                     NaN
# 1        missense_variant              0.9031                     NaN
# 2        missense_variant              0.9031                     NaN
# 3        missense_variant              0.9031                     NaN
# 4        missense_variant              0.4523                     NaN
# ...                   ...                 ...                     ...
# 1053709  missense_variant           -2.049575                     NaN
# 1053710  missense_variant            0.106511                     NaN
# 1053711  missense_variant           -2.459162                     NaN
# 1053712  missense_variant           -2.736793                     NaN
# 1053713  missense_variant            0.193065                     NaN
#
#         auth_reported_func_class  auth_reported_normal_min  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 1053709                      0.0                     -1.11
# 1053710                      1.0                     -1.11
# 1053711                      0.0                     -1.11
# 1053712                      0.0                     -1.11
# 1053713                      1.0                     -1.11
#
#          auth_reported_normal_max  auth_reported_abnormal_min  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 1053709                      0.89                       -5.76
# 1053710                      0.89                       -5.76
# 1053711                      0.89                       -5.76
# 1053712                      0.89                       -5.76
# 1053713                      0.89                       -5.76
#
#          auth_reported_abnormal_max splice_measure  gnomad_MAF clinvar_sig  \
# 0                               NaN             No    0.000002         NaN
# 1                               NaN             No         NaN         NaN
# 2                               NaN             No         NaN         NaN
# 3                               NaN             No         NaN         NaN
# 4                               NaN             No         NaN         NaN
# ...                             ...            ...         ...         ...
# 1053709                       -2.13             No         NaN         NaN
# 1053710                       -2.13             No         NaN         NaN
# 1053711                       -2.13             No         NaN         NaN
# 1053712                       -2.13             No         NaN         NaN
# 1053713                       -2.13             No         NaN         NaN
#
#         clinvar_star clinvar_date_last_reviewed nucleotide_or_aa  \
# 0                NaN                        NaN               aa
# 1                NaN                        NaN               aa
# 2                NaN                        NaN               aa
# 3                NaN                        NaN               aa
# 4                NaN                        NaN               aa
# ...              ...                        ...              ...
# 1053709          NaN                        NaN               aa
# 1053710          NaN                        NaN               aa
# 1053711          NaN                        NaN               aa
# 1053712          NaN                        NaN               aa
# 1053713          NaN                        NaN               aa
#
#           MaveDB URN (score set) Ensembl_transript_ID Ref_seq_transcript_ID  \
# 0        urn:mavedb:00000657-a-1    ENST00000263080.3           NM_000049.4
# 1        urn:mavedb:00000657-a-1    ENST00000263080.3           NM_000049.4
# 2        urn:mavedb:00000657-a-1    ENST00000263080.3           NM_000049.4
# 3        urn:mavedb:00000657-a-1    ENST00000263080.3           NM_000049.4
# 4        urn:mavedb:00000657-a-1    ENST00000263080.3           NM_000049.4
# ...                          ...                  ...                   ...
# 1053709  urn:mavedb:00000054-a-1    ENST00000371953.8           NM_000314.6
# 1053710  urn:mavedb:00000054-a-1    ENST00000371953.8           NM_000314.6
# 1053711  urn:mavedb:00000054-a-1    ENST00000371953.8           NM_000314.6
# 1053712  urn:mavedb:00000054-a-1    ENST00000371953.8           NM_000314.6
# 1053713  urn:mavedb:00000054-a-1    ENST00000371953.8           NM_000314.6
#
#                      Model_system      Assay_type Phenotype_measured  \
# 0        immortalized human cells        Reporter       Fluorescence
# 1        immortalized human cells        Reporter       Fluorescence
# 2        immortalized human cells        Reporter       Fluorescence
# 3        immortalized human cells        Reporter       Fluorescence
# 4        immortalized human cells        Reporter       Fluorescence
# ...                           ...             ...                ...
# 1053709                     yeast  Cell Viability        Cell growth
# 1053710                     yeast  Cell Viability        Cell growth
# 1053711                     yeast  Cell Viability        Cell growth
# 1053712                     yeast  Cell Viability        Cell growth
# 1053713                     yeast  Cell Viability        Cell growth
#
#                    Phenotype_detail IGVF_produced simplified_consequence Flag  \
# 0                 protein stability            No               Missense  NaN
# 1                 protein stability            No               Missense  NaN
# 2                 protein stability            No               Missense  NaN
# 3                 protein stability            No               Missense  NaN
# 4                 protein stability            No               Missense  NaN
# ...                             ...           ...                    ...  ...
# 1053709  lipid phosphatase activity            No               Missense  NaN
# 1053710  lipid phosphatase activity            No               Missense  NaN
# 1053711  lipid phosphatase activity            No               Missense  NaN
# 1053712  lipid phosphatase activity            No               Missense  NaN
# 1053713  lipid phosphatase activity            No               Missense  NaN
#
#         CHROM        POS  REF  ALT  DS_AG  DS_AL  DS_DG  DS_DL  DP_AG  DP_AL  \
# 0        17.0  3476163.0    A    G    0.0    0.0    0.0    0.0  -29.0  -22.0
# 1        17.0  3476163.0    A    G    0.0    0.0    0.0    0.0  -29.0  -22.0
# 2        17.0  3476163.0    A    G    0.0    0.0    0.0    0.0  -29.0  -22.0
# 3        17.0  3476163.0    A    G    0.0    0.0    0.0    0.0  -29.0  -22.0
# 4         NaN        NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...       ...        ...  ...  ...    ...    ...    ...    ...    ...    ...
# 1053709   NaN        NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1053710   NaN        NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1053711   NaN        NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1053712   NaN        NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1053713   NaN        NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#          DP_DG  DP_DL  SpliceAI_score
# 0         35.0  -29.0             0.0
# 1         35.0  -29.0             0.0
# 2         35.0  -29.0             0.0
# 3         35.0  -29.0             0.0
# 4          NaN    NaN             NaN
# ...        ...    ...             ...
# 1053709    NaN    NaN             NaN
# 1053710    NaN    NaN             NaN
# 1053711    NaN    NaN             NaN
# 1053712    NaN    NaN             NaN
# 1053713    NaN    NaN             NaN
#
# [1053714 rows x 57 columns]
